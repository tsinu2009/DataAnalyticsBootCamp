# %%
import pandas as pd
import numpy as np

# %%
Location = 'datasets/diamonds.csv'
df = pd.read_csv(Location)
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.corr()
# Out:
#             Unnamed: 0     carat     depth     table     price         x  \
# Unnamed: 0    1.000000 -0.377983 -0.034800 -0.100830 -0.306873 -0.405440
# carat        -0.377983  1.000000  0.028224  0.181618  0.921591  0.975094
# depth        -0.034800  0.028224  1.000000 -0.295779 -0.010647 -0.025289
# table        -0.100830  0.181618 -0.295779  1.000000  0.127134  0.195344
# price        -0.306873  0.921591 -0.010647  0.127134  1.000000  0.884435
# x            -0.405440  0.975094 -0.025289  0.195344  0.884435  1.000000
# y            -0.395843  0.951722 -0.029341  0.183760  0.865421  0.974701
# z            -0.399208  0.953387  0.094924  0.150929  0.861249  0.970772
#
#                    y         z
# Unnamed: 0 -0.395843 -0.399208
# carat       0.951722  0.953387
# depth      -0.029341  0.094924
# table       0.183760  0.150929
# price       0.865421  0.861249
# x           0.974701  0.970772
# y           1.000000  0.952006
# z           0.952006  1.000000

# %%
import statsmodels.formula.api as smf

# %%
result = smf.ols('price ~ cut + color + carat', data=df).fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.871
# Model:                            OLS   Adj. R-squared:                  0.871
# Method:                 Least Squares   F-statistic:                 3.315e+04
# Date:                Wed, 05 Dec 2018   Prob (F-statistic):               0.00
# Time:                        10:11:42   Log-Likelihood:            -4.6851e+05
# No. Observations:               53940   AIC:                         9.370e+05
# Df Residuals:                   53928   BIC:                         9.372e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
result = smf.ols('price ~ color + carat + clarity', data=df).fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.914
# Model:                            OLS   Adj. R-squared:                  0.914
# Method:                 Least Squares   F-statistic:                 4.092e+04
# Date:                Wed, 05 Dec 2018   Prob (F-statistic):               0.00
# Time:                        10:16:35   Log-Likelihood:            -4.5762e+05
# No. Observations:               53940   AIC:                         9.153e+05
# Df Residuals:                   53925   BIC:                         9.154e+05
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
result = smf.ols('price ~ carat + depth + table', data=df).fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.854
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                 1.049e+05
# Date:                Wed, 05 Dec 2018   Prob (F-statistic):               0.00
# Time:                        10:20:12   Log-Likelihood:            -4.7194e+05
# No. Observations:               53940   AIC:                         9.439e+05
# Df Residuals:                   53936   BIC:                         9.439e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     1.3e+04    390.918     33.264      0.000    1.22e+04    1.38e+04
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline
#sns.set_style('darkgrid') #my default is "whitegrid"

# %%
df = pd.read_csv("datasets/diamonds.csv", encoding = "ISO-8859-1") #1st column needs encoding to read pound/hashtag(#) symbol
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.rename(columns={'Unnamed: 0':'Number'}, inplace = True)

# %%
df.head()
# Out:
#    Number  carat      cut color clarity  depth  table  price     x     y     z
# 0       1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.rename(columns={'Number':'MyNumber'}, inplace = True)

# %%
df.head()
# Out:
#    MyNumber  carat      cut color clarity  depth  table  price     x     y  \
# 0         1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1         2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2         3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3         4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4         5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.set_index('MyNumber', inplace=True)
df.head()
# Out:
#           carat      cut color clarity  depth  table  price     x     y     z
# MyNumber
# 1          0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2          0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3          0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4          0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5          0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.lmplot(x='price',y='carat', data=df)

# %%
sns.lmplot(x='price', y='carat', data=df, 
           fit_reg=False, 
           hue='table')

# %%
sns.lmplot(x='carat',y='depth', data=df)

# %%
sns.lmplot(x='price', y='carat', data=df, 
           fit_reg=False, 
           hue='color')

# %%
sns.boxplot(data=df)

# %%
stats_df = df.drop(['carat', 'color', 'price'], axis=1)
stats_df.head()
# Out:
#               cut clarity  depth  table     x     y     z
# MyNumber
# 1           Ideal     SI2   61.5   55.0  3.95  3.98  2.43
# 2         Premium     SI1   59.8   61.0  3.89  3.84  2.31
# 3            Good     VS1   56.9   65.0  4.05  4.07  2.31
# 4         Premium     VS2   62.4   58.0  4.20  4.23  2.63
# 5            Good     SI2   63.3   58.0  4.34  4.35  2.75

# %%
df.head()
# Out:
#           carat      cut color clarity  depth  table  price     x     y     z
# MyNumber
# 1          0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2          0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3          0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4          0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5          0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
stats_df.head()
# Out:
#               cut clarity  depth  table     x     y     z
# MyNumber
# 1           Ideal     SI2   61.5   55.0  3.95  3.98  2.43
# 2         Premium     SI1   59.8   61.0  3.89  3.84  2.31
# 3            Good     VS1   56.9   65.0  4.05  4.07  2.31
# 4         Premium     VS2   62.4   58.0  4.20  4.23  2.63
# 5            Good     SI2   63.3   58.0  4.34  4.35  2.75

# %%
sns.boxplot(data=stats_df)

# %%
plt.subplots(figsize=(15,7))
sns.violinplot(x='clarity', y='price', data=df)

# %%
#create color palette
#color Hex numbers are from Bulbapedia (https://bulbapedia.bulbagarden.net/wiki/Category:Type_color_templates)
pkmn_type_colors = ['#78C850',  # Grass
                    '#F08030',  # Fire
                    '#6890F0',  # Water
                    '#A8B820',  # Bug
                    '#A8A878',  # Normal
                    '#A040A0',  # Poison
                    '#F8D030',  # Electric
                    '#E0C068',  # Ground
                    '#EE99AC',  # Fairy
                    '#C03028',  # Fighting
                    '#F85888',  # Psychic
                    '#B8A038',  # Rock
                    '#705898',  # Ghost
                    '#98D8D8',  # Ice
                    '#7038F8',  # Dragon
                   ]

# %%
plt.subplots(figsize=(13,7))
sns.violinplot(x='clarity', y='price', data=df)

# %%
plt.subplots(figsize=(10,6))
sns.swarmplot(x='depth', y='table', data=df, palette=pkmn_type_colors)

# %%
plt.subplots(figsize=(10,6))
sns.swarmplot(x='color', y='table', data=df, palette=pkmn_type_colors)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-f95821540ced> in <module>()
#       1 plt.subplots(figsize=(10,6))
# ----> 2 sns.swarmplot(x='color', y='table', data=df, palette=pkmn_type_colors)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in swarmplot(x, y, hue, data, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2779                        linewidth=linewidth))
#    2780
# -> 2781     plotter.plot(ax, kwargs)
#    2782     return ax
#    2783
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, kws)
#    1423     def plot(self, ax, kws):
#    1424         """Make the full plot."""
# -> 1425         self.draw_swarmplot(ax, kws)
#    1426         self.add_legend_data(ax)
#    1427         self.annotate_axes(ax)
#
# ...

# %%
corr = stats_df.corr()

sns.heatmap(corr, vmin=-1, annot=True)

# %%
#create a bar plot of Type 1 frequency
sns.countplot(x='color',
              data=df, 
              palette=pkmn_type_colors)

plt.xticks(rotation=-45)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]), <a list of 7 Text xticklabel objects>)

# %%
df.head()
# Out:
#           carat      cut color clarity  depth  table  price     x     y     z
# MyNumber
# 1          0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2          0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3          0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4          0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5          0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
sns.distplot(df['price'])

# %%
sns.distplot(df['carat'])

# %%
df.head()
# Out:
#           carat      cut color clarity  depth  table  price     x     y     z
# MyNumber
# 1          0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2          0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3          0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4          0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5          0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
melt_df = pd.melt(df, 
                  id_vars=['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price'], #column to keep
                  var_name="Stat")

melt_df.head()
# Out:
#    carat      cut color clarity  depth  table  price Stat  value
# 0   0.23    Ideal     E     SI2   61.5   55.0    326    x   3.95
# 1   0.21  Premium     E     SI1   59.8   61.0    326    x   3.89
# 2   0.23     Good     E     VS1   56.9   65.0    327    x   4.05
# 3   0.29  Premium     I     VS2   62.4   58.0    334    x   4.20
# 4   0.31     Good     J     SI2   63.3   58.0    335    x   4.34

# %%
melt_df.head()
# Out:
#    carat      cut color clarity  depth  table  price Stat  value
# 0   0.23    Ideal     E     SI2   61.5   55.0    326    x   3.95
# 1   0.21  Premium     E     SI1   59.8   61.0    326    x   3.89
# 2   0.23     Good     E     VS1   56.9   65.0    327    x   4.05
# 3   0.29  Premium     I     VS2   62.4   58.0    334    x   4.20
# 4   0.31     Good     J     SI2   63.3   58.0    335    x   4.34

# %%
sns.distplot(melt_df['value'])

# %%
plt.figure(figsize=(10,6))

#swarm plot of Stats from melted dataframe
sns.swarmplot(x='Stat', y='value', 
              data=melt_df,
              hue='Type 1')
